# %%
# 파일 열기
# 변수명 = open("파일경로/파일이름.txt", "모드")
new_file = open("sample.txt", "w")

# 파일 닫기
new_file.close()

# %% [markdown]
# ![filemode.png](data:image/png;base64,...)

# %%
# write(): 파일에 내용을 씁니다.
file = open("sample.txt", "w")
file.write("파일에 작성할 문자열")
file.close()

# %%
data = ["첫 번째 줄\n", "두 번째 줄\n", "세 번째 줄\n"]
file = open("sample.txt", "w")
file.writelines(data)
file.close()

# %%
# read() : 파일을 읽습니다.
file = open("sample.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# 첫 번째 줄
# 두 번째 줄
# 세 번째 줄

# %%
# readline() : 파일에서 한 줄씩 읽습니다.
file = open("sample.txt", "r")
line = file.readline()
while line:
    print(line)
    line = file.readline()
file.close()
# Out:
# 첫 번째 줄
#
# 두 번째 줄
#
# 세 번째 줄

# %%
# readlines() : 파일의 모든 라인을 각각의 문자열로 읽어 리스트로 반환합니다.
file = open("sample.txt", "r")
lines = file.readlines()
for line in lines:
    print(line)
file.close()
# Out:
# 첫 번째 줄
#
# 두 번째 줄
#
# 세 번째 줄

# %%
# 파일 이어 쓰기
file = open("sample.txt", "a")
file.write("파일에 작성할 문자열1\n")
file.write("파일에 작성할 문자열2\n")
file.close()

# %%
# read() : 파일을 읽습니다.
file = open("sample.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# 첫 번째 줄
# 두 번째 줄
# 세 번째 줄
# 파일에 작성할 문자열1
# 파일에 작성할 문자열2

# %%
# with문을 사용하여 파일 자동으로 close 하기
with open('sample.txt', 'w') as file:
  file.write("파일에 작성할 문자열1\n")
  file.write("파일에 작성할 문자열2\n")

# %%
# read() : 파일을 읽습니다.
file = open("sample.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# 파일에 작성할 문자열1
# 파일에 작성할 문자열2

# %%
# 파일 입출력 오류 처리
try:
    with open('sample.txt', 'r') as file:
        content = file.read()
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")
except PermissionError:
    print("파일을 열 권한이 없습니다.")
except IOError as e:
    print(f"파일 읽기 오류: {e}")

# %% [markdown]
# ![fileerror.png](data:image/png;base64,...)
