# %%
text = "Hello World!"
reversed_text = "".join(reversed(text))
print(reversed_text)
# Out:
# !dlroW olleH

# %%
text = "Hello World!"
reversed_text = text[::-1]
print(reversed_text)
# Out:
# !dlroW olleH
